# %%
import pandas as pd

# %%
fpath ='./Learning6.xlsx'

# %%
df_students = pd.read_excel(fpath)

# %%
df_students
# Out:
#     Unnamed: 0  Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4 Unnamed: 5  \
# 0          NaN         NaN         NaN         NaN         NaN        NaN
# 1          NaN         NaN         NaN         NaN         NaN        NaN
# 2          NaN         NaN         NaN         NaN         NaN       Name
# 3          NaN         NaN         NaN         NaN         NaN        Kay
# 4          NaN         NaN         NaN         NaN         NaN        NaN
# 5          NaN         NaN         NaN         NaN         NaN        NaN
# 6          NaN         NaN         NaN         NaN         NaN        NaN
# 7          NaN         NaN         NaN         NaN         NaN        Man
# 8          NaN         NaN         NaN         NaN         NaN        NaN
# 9          NaN         NaN         NaN         NaN         NaN        NaN
# 10         NaN         NaN         NaN         NaN         NaN        NaN
# 11         NaN         NaN         NaN         NaN         NaN       Kong
# ...

# %%
df_students2 = pd.read_excel(fpath, header = 3)

# %%
df_students2
# Out:
#     Unnamed: 0  Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  Name  Subject  \
# 0          NaN         NaN         NaN         NaN         NaN   Kay  Chinese
# 1          NaN         NaN         NaN         NaN         NaN   NaN    Maths
# 2          NaN         NaN         NaN         NaN         NaN   NaN  English
# 3          NaN         NaN         NaN         NaN         NaN   NaN      NaN
# 4          NaN         NaN         NaN         NaN         NaN   Man  Chinese
# 5          NaN         NaN         NaN         NaN         NaN   NaN    Maths
# 6          NaN         NaN         NaN         NaN         NaN   NaN  English
# 7          NaN         NaN         NaN         NaN         NaN   NaN      NaN
# 8          NaN         NaN         NaN         NaN         NaN  Kong  Chinese
# 9          NaN         NaN         NaN         NaN         NaN   NaN      NaN
# 10         NaN         NaN         NaN         NaN         NaN   NaN  English
#
#     Score
# 0    70.0
# ...

# %%
# skip NaN rows and Nan columns
total_cols = len(df_students.columns)
df_students3 = pd.read_excel(fpath, header =3, usecols = range(5,total_cols))

# %%
df_students3
# Out:
#     Name  Subject  Score
# 0    Kay  Chinese   70.0
# 1    NaN    Maths   80.0
# 2    NaN  English   90.0
# 3    NaN      NaN    NaN
# 4    Man  Chinese   80.0
# 5    NaN    Maths  100.0
# 6    NaN  English    NaN
# 7    NaN      NaN    NaN
# 8   Kong  Chinese   88.0
# 9    NaN      NaN   70.0
# 10   NaN  English   70.0

# %%
# check if cell is null or not
df_students2.isnull()
# Out:
#     Unnamed: 0  Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4   Name  \
# 0         True        True        True        True        True  False
# 1         True        True        True        True        True   True
# 2         True        True        True        True        True   True
# 3         True        True        True        True        True   True
# 4         True        True        True        True        True  False
# 5         True        True        True        True        True   True
# 6         True        True        True        True        True   True
# 7         True        True        True        True        True   True
# 8         True        True        True        True        True  False
# 9         True        True        True        True        True   True
# 10        True        True        True        True        True   True
#
#     Subject  Score
# 0     False  False
# 1     False  False
# 2     False  False
# 3      True   True
# 4     False  False
# ...

# %%
df_students2['Score'].isnull()
# Out:
# 0     False
# 1     False
# 2     False
# 3      True
# 4     False
# 5     False
# 6      True
# 7      True
# 8     False
# 9     False
# 10    False
# Name: Score, dtype: bool

# %%
df_students2['Score'].notnull()
# Out:
# 0      True
# 1      True
# 2      True
# 3     False
# 4      True
# 5      True
# 6     False
# 7     False
# 8      True
# 9      True
# 10     True
# Name: Score, dtype: bool

# %%
#remove all Nan columns
df_students2.dropna(axis =1,how = 'all', inplace=True)

# %%
df_students2
# Out:
#     Name  Subject  Score
# 0    Kay  Chinese   70.0
# 1    NaN    Maths   80.0
# 2    NaN  English   90.0
# 3    NaN      NaN    NaN
# 4    Man  Chinese   80.0
# 5    NaN    Maths  100.0
# 6    NaN  English    NaN
# 7    NaN      NaN    NaN
# 8   Kong  Chinese   88.0
# 9    NaN      NaN   70.0
# 10   NaN  English   70.0

# %%
#remove all Nan Rows
df_students2.dropna(axis =0, how ='all', inplace = True)

# %%
df_students2
# Out:
#     Name  Subject  Score
# 0    Kay  Chinese   70.0
# 1    NaN    Maths   80.0
# 2    NaN  English   90.0
# 4    Man  Chinese   80.0
# 5    NaN    Maths  100.0
# 6    NaN  English    NaN
# 8   Kong  Chinese   88.0
# 9    NaN      NaN   70.0
# 10   NaN  English   70.0

# %%
# some of the rows'Name are still missing, fill it
df_students2.loc[:,'Name'] = df_students2['Name'].ffill()

# %%
df_students2
# Out:
#     Name  Subject  Score
# 0    Kay  Chinese   70.0
# 1    Kay    Maths   80.0
# 2    Kay  English   90.0
# 4    Man  Chinese   80.0
# 5    Man    Maths  100.0
# 6    Man  English    NaN
# 8   Kong  Chinese   88.0
# 9   Kong      NaN   70.0
# 10  Kong  English   70.0

# %%
# Kong'subject is missing Maths, let's fill it
df_students2.loc[9:'Subject'] = df_students2.loc[9:'Subject'].fillna('Maths')

# %%
df_students2
# Out:
#     Name  Subject  Score
# 0    Kay  Chinese   70.0
# 1    Kay    Maths   80.0
# 2    Kay  English   90.0
# 4    Man  Chinese   80.0
# 5    Man    Maths  100.0
# 6    Man  English    NaN
# 8   Kong  Chinese   88.0
# 9   Kong    Maths   70.0
# 10  Kong  English   70.0

# %%
# NaN Score = 0
df_students2['Score'] = df_students2['Score'].fillna(0)

# %%
df_students2
# Out:
#     Name  Subject  Score
# 0    Kay  Chinese   70.0
# 1    Kay    Maths   80.0
# 2    Kay  English   90.0
# 4    Man  Chinese   80.0
# 5    Man    Maths  100.0
# 6    Man  English    0.0
# 8   Kong  Chinese   88.0
# 9   Kong    Maths   70.0
# 10  Kong  English   70.0

# %%
#Save clean data

# %%
clean_data = 'Learning6_Clean.xlsx'
import os
if os.path.exists(clean_data):
    print(f"\n文件 {clean_data} existed,pass")
else:
    df_students2.to_excel(clean_data, index=False)
    print(f"\nalready saved to be excel file: {clean_data}")
# Out:
# 文件 Learning6_Clean.xlsx existed,pass
